# %%
# %pip install imgaug
# Out:
# ...
#   WARNING: The scripts lsm2bin.exe, tiff2fsspec.exe, tiffcomment.exe and tifffile.exe are installed in 'c:\Users\ak135\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin.exe and imageio_remove_bin.exe are installed in 'c:\Users\ak135\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#    ---------------------------------------- 0.0/948.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/948.0 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/948.0 kB ? eta -:--:--
#    --------------------- ---------------- 524.3/948.0 kB 840.2 kB/s eta 0:00:01
#    ------------------------------- ------ 786.4/948.0 kB 860.9 kB/s eta 0:00:01
# ...

# %%
# %pip install albumentations
# Out:
# ...
#   Using cached albucore-0.0.23-py3-none-any.whl.metadata (5.3 kB)
# ...
# Using cached albucore-0.0.23-py3-none-any.whl (14 kB)
# ...
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.4 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.0/39.4 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.3/39.4 MB 2.1 MB/s eta 0:00:19
#    - -------------------------------------- 1.6/39.4 MB 1.8 MB/s eta 0:00:21
#    - -------------------------------------- 1.8/39.4 MB 1.7 MB/s eta 0:00:23
#    -- ------------------------------------- 2.1/39.4 MB 1.6 MB/s eta 0:00:24
#    -- ------------------------------------- 2.4/39.4 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.6/39.4 MB 1.5 MB/s eta 0:00:26
#    -- ------------------------------------- 2.9/39.4 MB 1.4 MB/s eta 0:00:26
#    -- ------------------------------------- 2.9/39.4 MB 1.4 MB/s eta 0:00:26
# ...

# %%
# %pip install shutil
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
# ERROR: No matching distribution found for shutil

# %%
# %pip install h5py imgaug numpy pandas seaborn matplotlib pillow scikit-image keras scikit-learn mlxtend opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade dhutil
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/826.8 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/826.8 kB ? eta -:--:--
#    ------------------------ ------------- 524.3/826.8 kB 985.5 kB/s eta 0:00:01
#    ------------------------ ------------- 524.3/826.8 kB 985.5 kB/s eta 0:00:01
#    ---------------------------------------- 826.8/826.8 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('D:/Chest_xray/chest_xray/chest_xray'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:/Chest_xray/chest_xray/chest_xray\test\.DS_Store
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0001-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0003-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0005-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0006-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0007-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0009-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0010-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0011-0001-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0011-0001-0002.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0011-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0013-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0015-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0016-0001.jpeg
# ...

# %%
# %pip install albumentations
# Out:
# ...
#   WARNING: The scripts sz_split.exe and sz_wc.exe are installed in 'c:\Users\ak135\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\ak135\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 837.5 kB/s eta 0:00:46
#     --------------------------------------- 0.8/38.8 MB 838.9 kB/s eta 0:00:46
#     --------------------------------------- 0.8/38.8 MB 838.9 kB/s eta 0:00:46
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('D:/Chest_xray/chest_xray/chest_xray'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:/Chest_xray/chest_xray/chest_xray\.DS_Store
# D:/Chest_xray/chest_xray/chest_xray\test\.DS_Store
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0001-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0003-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0005-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0006-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0007-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0009-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0010-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0011-0001-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0011-0001-0002.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0011-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0013-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0015-0001.jpeg
# D:/Chest_xray/chest_xray/chest_xray\test\NORMAL\IM-0016-0001.jpeg
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
# Replace the problematic import with the updated import path
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150

def get_training_data(data_dir):
    images = []  # Store image data
    classes = []  # Store corresponding labels
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))  # Reshaping images to preferred size
                images.append(resized_arr)  # Add image data
                classes.append(class_num)  # Add label
            except Exception as e:
                print(f"Error processing image {img}: {e}")
    return np.array(images), np.array(classes)

# %%
train = get_training_data('D:/Pneumonia/chest_xray/chest_xray/train')
test = get_training_data('D:/Pneumonia/chest_xray/chest_xray/test')
val = get_training_data('D:/Pneumonia/chest_xray/chest_xray/val')
# Out:
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
train = get_training_data('chest_xray/chest_xray/train')
test = get_training_data('chest_xray/chest_xray/test')
val = get_training_data('chest_xray/chest_xray/val')
# Out:
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
train_images, train_labels = get_training_data('D:/Pneumonia/chest_xray/chest_xray/train')
test_images, test_labels = get_training_data('D:/Pneumonia/chest_xray/chest_xray/test')
val_images, val_labels = get_training_data('D:/Pneumonia/chest_xray/chest_xray/val')
# Out:
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
train_images, train_labels = get_training_data('chest_xray/chest_xray/train')
test_images, test_labels = get_training_data('chest_xray/chest_xray/test')
val_images, val_labels = get_training_data('chest_xray/chest_xray/val')
# Out:
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
#
# Error processing image .DS_Store: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
import seaborn as sns
# Map the labels to corresponding class names
l = ["Pneumonia" if label == 0 else "Normal" for label in train_labels]
# Plot the countplot
sns.set_style('darkgrid')
sns.countplot(x=l)
plt.title('Distribution of Classes in Training Data')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
import seaborn as sns
# Map the labels to corresponding class names
l = ["Pneumonia" if label == 0 else "Normal" for label in train_labels]
# Plot the countplot
sns.set_style('darkgrid')
sns.countplot(x=l)
plt.title('Distribution of Classes in Training Data')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
# Plot the first image
plt.figure(figsize=(5, 5))
plt.imshow(train_images[0], cmap='gray')  # Using train_images for images
plt.title(labels[train_labels[0]])  # Using train_labels for labels
plt.show()

# Plot the last image
plt.figure(figsize=(5, 5))
plt.imshow(train_images[-1], cmap='gray')  # Using train_images for images
plt.title(labels[train_labels[-1]])  # Using train_labels for labels
plt.show()

# %%
# Plot the first image
plt.figure(figsize=(5, 5))
plt.imshow(train_images[0], cmap='gray')  # Using train_images for images
plt.title(labels[train_labels[0]])  # Using train_labels for labels
plt.show()

# Plot the last image
plt.figure(figsize=(5, 5))
plt.imshow(train_images[-1], cmap='gray')  # Using train_images for images
plt.title(labels[train_labels[-1]])  # Using train_labels for labels
plt.show()

# %%
import os
import random
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img

# Base directory for your dataset
base_dir = "D:/Chest_xray/chest_xray/chest_xray/train"

# Labels
labels = ['PNEUMONIA', 'NORMAL']

def display_images(base_dir, label, num_images=5):
    """
    Function to display 'num_images' for a given label (PNEUMONIA or NORMAL)
    """
    label_path = os.path.join(base_dir, label)
    image_files = os.listdir(label_path)
    
    # Randomly select 'num_images' files
    selected_images = random.sample(image_files, num_images)
    
    plt.figure(figsize=(15, 5))
    for i, img_name in enumerate(selected_images):
        img_path = os.path.join(label_path, img_name)
        img = load_img(img_path, target_size=(150, 150), color_mode='grayscale')  # Load the image
        
        plt.subplot(1, num_images, i + 1)
        plt.imshow(img, cmap='gray')  # Display the image in grayscale
        plt.title(label)
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Display 5 images for PNEUMONIA
print("Images for PNEUMONIA:")
display_images(base_dir, "PNEUMONIA", num_images=5)

# Display 5 images for NORMAL
print("Images for NORMAL:")
display_images(base_dir, "NORMAL", num_images=5)
# Out:
# Images for PNEUMONIA:
# Images for NORMAL:

# %%
import os
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import random

# Define the base directory for your dataset
base_dir = "D:/Pneumonia/chest_xray/chest_xray/train"

# List of class names (subfolder names in the dataset)
classes = ['PNEUMONIA', 'NORMAL']

# Function to visualize images
def visualize_images(path, num_images=4):
    # Get a list of all images in the folder
    image_files = os.listdir(path)

    # Randomly select the specified number of images
    selected_images = random.sample(image_files, num_images)

    # Plot the selected images
    plt.figure(figsize=(10, 10))
    for i, img_name in enumerate(selected_images):
        img_path = os.path.join(path, img_name)
        img = load_img(img_path, target_size=(256, 256))  # Load and resize image
        img_array = img_to_array(img) / 255.0  # Normalize image

        # Add to plot
        plt.subplot(1, num_images, i + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(img_name)

    # Show the plot
    plt.tight_layout()
    plt.show()

# Iterate through each class folder to visualize images
for label in classes:
    # Specify the path containing the images to visualize
    path_to_visualize = os.path.join(base_dir, label)

    # Print the label and visualize 4 images
    print(label.upper())
    visualize_images(path_to_visualize, num_images=4)
# Out:
# PNEUMONIA
# NORMAL

# %%
import os
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import random

# Define the base directory for your dataset
base_dir = "chest_xray/chest_xray/train"

# List of class names (subfolder names in the dataset)
classes = ['PNEUMONIA', 'NORMAL']

# Function to visualize images
def visualize_images(path, num_images=4):
    # Get a list of all images in the folder
    image_files = os.listdir(path)

    # Randomly select the specified number of images
    selected_images = random.sample(image_files, num_images)

    # Plot the selected images
    plt.figure(figsize=(10, 10))
    for i, img_name in enumerate(selected_images):
        img_path = os.path.join(path, img_name)
        img = load_img(img_path, target_size=(256, 256))  # Load and resize image
        img_array = img_to_array(img) / 255.0  # Normalize image

        # Add to plot
        plt.subplot(1, num_images, i + 1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(img_name)

    # Show the plot
    plt.tight_layout()
    plt.show()

# Iterate through each class folder to visualize images
for label in classes:
    # Specify the path containing the images to visualize
    path_to_visualize = os.path.join(base_dir, label)

    # Print the label and visualize 4 images
    print(label.upper())
    visualize_images(path_to_visualize, num_images=4)
# Out:
# PNEUMONIA
# NORMAL

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

# Loop through the train_images and train_labels
for i in range(len(train_images)):
    x_train.append(train_images[i])
    y_train.append(train_labels[i])

# Loop through the test_images and test_labels
for i in range(len(test_images)):
    x_test.append(test_images[i])
    y_test.append(test_labels[i])

# Loop through the val_images and val_labels
for i in range(len(val_images)):
    x_val.append(val_images[i])
    y_val.append(val_labels[i])

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

# Loop through the train_images and train_labels
for i in range(len(train_images)):
    x_train.append(train_images[i])
    y_train.append(train_labels[i])

# Loop through the test_images and test_labels
for i in range(len(test_images)):
    x_test.append(test_images[i])
    y_test.append(test_labels[i])

# Loop through the val_images and val_labels
for i in range(len(val_images)):
    x_val.append(val_images[i])
    y_val.append(val_labels[i])

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# d:\Anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.2, min_lr=0.000001)

history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 15 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/15
# d:\Anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 137s 820ms/step - accuracy: 0.7803 - loss: 1.2923 - val_accuracy: 0.5000 - val_loss: 39.4133 - learning_rate: 0.0010
# Epoch 2/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 133s 816ms/step - accuracy: 0.8730 - loss: 0.3071 - val_accuracy: 0.5000 - val_loss: 29.7500 - learning_rate: 0.0010
# Epoch 3/15
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.9023 - loss: 0.2594
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# ...

# %%
print("Accuracy of the model is - " , model.evaluate(x_train,y_train)[1]*100 , "%")
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.9221 - loss: 0.1890
# Accuracy of the model is -  93.36656332015991 %

# %%
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9381 - loss: 0.1759
# Accuracy of the model is -  90.54487347602844 %

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, roc_auc_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Predict on the test set
y_pred = (model.predict(x_test) > 0.5).astype("int32")  # Binary classification threshold of 0.5

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.title("Confusion Matrix")
plt.ylabel("Actual")
plt.xlabel("Predicted")
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step

# %%
# Classification Report
report = classification_report(y_test, y_pred, target_names=labels)
print("Classification Report:\n", report)

# Precision, Recall, F1-Score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1-Score: {f1:.2f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#    PNEUMONIA       0.90      0.96      0.93       390
#       NORMAL       0.92      0.82      0.87       234
#
#     accuracy                           0.91       624
#    macro avg       0.91      0.89      0.90       624
# weighted avg       0.91      0.91      0.90       624
#
# Precision: 0.92
# Recall: 0.82
# F1-Score: 0.87

# %%
# ROC Curve and AUC
y_pred_prob = model.predict(x_test).ravel()  # Predicted probabilities
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}", color="blue")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()
print(f"AUC: {roc_auc:.2f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step
# AUC: 0.95

# %%
# Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

# PSNR
def calculate_psnr(true, pred):
    mse_value = mean_squared_error(true, pred)
    if mse_value == 0:
        return 100  # Perfect prediction
    max_pixel = 1.0  # For normalized data
    psnr_value = 20 * math.log10(max_pixel / math.sqrt(mse_value))
    return psnr_value

psnr = calculate_psnr(y_test, y_pred)
print(f"PSNR: {psnr:.2f}")
# Out:
# Mean Squared Error: 0.09
# PSNR: 10.24
